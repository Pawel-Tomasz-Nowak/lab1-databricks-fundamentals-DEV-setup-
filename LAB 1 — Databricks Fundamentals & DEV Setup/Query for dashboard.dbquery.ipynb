-- %%
SELECT type, soldOn, lastSoldPrice, beds, baths FROM dbr_dev.pawelnowak2004pri219.alabama_real_estate :param_1 :param_2 :param_1
-- Out:
-- Databricks visualization. Run in Databricks to view.
-- Databricks visualization. Run in Databricks to view.
-- Databricks visualization. Run in Databricks to view.
